# %%
import pandas as pd

# %% [markdown]
# Read the "bus_clean.csv" file

# %%
bus = pd.read_csv("processdata/bus_clean.csv", parse_dates=["service_date", "scheduled_dt", "actual_dt"]) #convert dates to datetime64 type
print("Loaded bus_clean.csv:", bus.shape) #sanity check row and col numbers
# Out:
# Loaded bus_clean.csv: (54144994, 13)

# %%
weather_2023 = pd.read_csv("rawdata/2023bostonweather.csv") #read in the file
weather_2024 = pd.read_csv("rawdata/2024bostonweather.csv")

weather_raw = pd.concat([weather_2023, weather_2024], ignore_index=True) #merge two files
print("Loaded weather data:", weather_raw.shape) #sanity check row and col numbers
# Out:
# Loaded weather data: (17544, 22)

# %% [markdown]
# Remove uselss columns

# %%
cols_to_drop = [c for c in weather_raw.columns if c.endswith("_source")] 
cols_to_drop += ["wpgt"]
weather_raw = weather_raw.drop(columns=cols_to_drop, errors="ignore")

# %% [markdown]
# Create hour-level timestamp to help merge with "bus_clean.csv"

# %%
weather_raw["timestamp_hour"] = pd.to_datetime(
    weather_raw[["year", "month", "day", "hour"]]
)

# %% [markdown]
# Select the columns we want to keep as potential features.

# %%
keep_weather_cols = [
    "timestamp_hour",
    "temp", "rhum", "prcp", "wdir", "wspd", "pres", "cldc", "coco"
]
weather = weather_raw[keep_weather_cols].copy()

# %% [markdown]
# Rename columns

# %%
weather = weather.rename(columns={
    "temp": "air_temp_c",
    "rhum": "rel_humidity_pct",
    "prcp": "precip_mm",
    "wdir": "wind_dir_deg",
    "wspd": "wind_speed_kmh",
    "pres": "pressure_hpa",
    "cldc": "cloud_cover",
    "coco": "weather_condition"
})

# %% [markdown]
# Assign name to "weather_condition" for different weather conditions

# %%
weather_condition_map = {
    1: "Clear",
    2: "Fair",
    3: "Cloudy",
    4: "Overcast",
    5: "Fog",
    6: "Freezing Fog",
    7: "Light Rain",
    8: "Rain",
    9: "Heavy Rain",
    10: "Freezing Rain",
    11: "Heavy Freezing Rain",
    12: "Sleet",
    13: "Heavy Sleet",
    14: "Light Snowfall",
    15: "Snowfall",
    16: "Heavy Snowfall",
    17: "Rain Shower",
    18: "Heavy Rain Shower",
    19: "Sleet Shower",
    20: "Heavy Sleet Shower",
    21: "Snow Shower",
    22: "Heavy Snow Shower",
    23: "Lightning",
    24: "Hail",
    25: "Thunderstorm",
    26: "Heavy Thunderstorm",
    27: "Storm"
}

# Apply mapping
weather["weather_condition"] = weather["weather_condition"].map(weather_condition_map)

#  Check results
print(weather["weather_condition"].head(10))
# Out:
# 0    Light Rain
# 1    Light Rain
# 2    Light Rain
# 3    Light Rain
# 4    Light Rain
# 5    Light Rain
# 6    Light Rain
# 7    Light Rain
# 8      Overcast
# 9      Overcast
# Name: weather_condition, dtype: object

# %%
weather.head(5)
# Out:
#        timestamp_hour  air_temp_c  rel_humidity_pct  precip_mm  wind_dir_deg  \
# 0 2023-01-01 00:00:00        11.7               100        1.2           210
# 1 2023-01-01 01:00:00        11.1               100        0.3           190
# 2 2023-01-01 02:00:00        11.7               100        0.5           210
# 3 2023-01-01 03:00:00        11.1               100        1.8           200
# 4 2023-01-01 04:00:00        11.1               100        2.3           190
#
#    wind_speed_kmh  pressure_hpa  cloud_cover weather_condition
# 0            11.2        1010.4            8        Light Rain
# 1            11.2        1008.9            8        Light Rain
# 2            13.0        1008.2            8        Light Rain
# 3            11.2        1007.2            8        Light Rain
# 4            11.2        1006.2            8        Light Rain

# %%
bus.head(5)
# Out:
#   service_date  hour  weekday  is_weekend route_id direction_id  stop_id  \
# 0   2023-01-01     6        6           1       01      Inbound      110
# 1   2023-01-01     6        6           1       01      Inbound       67
# 2   2023-01-01     6        6           1       01      Inbound       72
# 3   2023-01-01     6        6           1       01      Inbound       75
# 4   2023-01-01     6        6           1       01      Inbound       79
#
#    time_point_order  point_type        scheduled_dt           actual_dt  \
# 0                 1  Startpoint 2023-01-01 06:05:00 2023-01-01 06:05:04
# 1                 2    Midpoint 2023-01-01 06:09:00 2023-01-01 06:06:28
# 2                 3    Midpoint 2023-01-01 06:12:00 2023-01-01 06:08:57
# 3                 4    Midpoint 2023-01-01 06:15:00 2023-01-01 06:12:41
# 4                 5    Midpoint 2023-01-01 06:19:00 2023-01-01 06:16:35
#
#    delay_seconds  delay_minutes
# 0            4.0       0.066667
# 1         -152.0      -2.533333
# 2         -183.0      -3.050000
# 3         -139.0      -2.316667
# 4         -145.0      -2.416667

# %% [markdown]
# Merge bus_clean table and weather table

# %%
bus["event_hour"] = bus["actual_dt"].dt.floor("h") #convert time into hous to match witrh timpestamp hour
bus_weather = pd.merge(
    bus,
    weather,
    left_on="event_hour",
    right_on="timestamp_hour",
    how="left"
)
bus_weather = bus_weather.drop(columns=["timestamp_hour"]) #remove duplicate columns

# %% [markdown]
# View the new table and save it

# %%
print("Merged shape:", bus_weather.shape)
print(bus_weather.head(10))
# Out:
# Merged shape: (54144994, 22)
#   service_date  hour  weekday  is_weekend route_id direction_id  stop_id  \
# 0   2023-01-01     6        6           1       01      Inbound      110
# 1   2023-01-01     6        6           1       01      Inbound       67
# 2   2023-01-01     6        6           1       01      Inbound       72
# 3   2023-01-01     6        6           1       01      Inbound       75
# 4   2023-01-01     6        6           1       01      Inbound       79
# 5   2023-01-01     6        6           1       01      Inbound      187
# 6   2023-01-01     6        6           1       01      Inbound       59
# 7   2023-01-01     6        6           1       01      Inbound      110
# 8   2023-01-01     6        6           1       01      Inbound       67
# 9   2023-01-01     6        6           1       01      Inbound       62
#
#    time_point_order  point_type        scheduled_dt  ... delay_minutes  \
# 0                 1  Startpoint 2023-01-01 06:05:00  ...      0.066667
# 1                 2    Midpoint 2023-01-01 06:09:00  ...     -2.533333
# 2                 3    Midpoint 2023-01-01 06:12:00  ...     -3.050000
# 3                 4    Midpoint 2023-01-01 06:15:00  ...     -2.316667
# 4                 5    Midpoint 2023-01-01 06:19:00  ...     -2.416667
# 5                 6    Midpoint 2023-01-01 06:21:00  ...      0.650000
# 6                 7    Midpoint 2023-01-01 06:25:00  ...     -1.066667
# 7                 1  Startpoint 2023-01-01 06:25:00  ...     -0.283333
# 8                 2    Midpoint 2023-01-01 06:29:00  ...     -2.016667
# 9                 8    Midpoint 2023-01-01 06:29:00  ...     -0.516667
#
#            event_hour  air_temp_c rel_humidity_pct  precip_mm  wind_dir_deg  \
# 0 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 1 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 2 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 3 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 4 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 5 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 6 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 7 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 8 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 9 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
#
#    wind_speed_kmh  pressure_hpa  cloud_cover  weather_condition
# 0            16.6        1004.1          8.0         Light Rain
# 1            16.6        1004.1          8.0         Light Rain
# 2            16.6        1004.1          8.0         Light Rain
# 3            16.6        1004.1          8.0         Light Rain
# 4            16.6        1004.1          8.0         Light Rain
# 5            16.6        1004.1          8.0         Light Rain
# 6            16.6        1004.1          8.0         Light Rain
# 7            16.6        1004.1          8.0         Light Rain
# 8            16.6        1004.1          8.0         Light Rain
# 9            16.6        1004.1          8.0         Light Rain
#
# [10 rows x 22 columns]

# %% [markdown]
# Check missing values

# %%
bus_weather.isna().sum()
# Out:
# service_date               0
# hour                       0
# weekday                    0
# is_weekend                 0
# route_id                   0
# direction_id               0
# stop_id                    0
# time_point_order           0
# point_type                 0
# scheduled_dt               0
# actual_dt            4283986
# delay_seconds        4283986
# delay_minutes        4283986
# event_hour           4283986
# air_temp_c           4283986
# rel_humidity_pct     4283986
# precip_mm            7739966
# wind_dir_deg         4283986
# wind_speed_kmh       4283986
# pressure_hpa         4283986
# cloud_cover          4283986
# weather_condition    4283986
# dtype: int64

# %% [markdown]
# Drop rows that contain missing values

# %%
bus_weather_clean = bus_weather.dropna()
print(bus_weather_clean.shape)
# Out:
# (46405028, 22)

# %%
bus_weather_clean.head(10)
# Out:
#   service_date  hour  weekday  is_weekend route_id direction_id  stop_id  \
# 0   2023-01-01     6        6           1       01      Inbound      110
# 1   2023-01-01     6        6           1       01      Inbound       67
# 2   2023-01-01     6        6           1       01      Inbound       72
# 3   2023-01-01     6        6           1       01      Inbound       75
# 4   2023-01-01     6        6           1       01      Inbound       79
# 5   2023-01-01     6        6           1       01      Inbound      187
# 6   2023-01-01     6        6           1       01      Inbound       59
# 7   2023-01-01     6        6           1       01      Inbound      110
# 8   2023-01-01     6        6           1       01      Inbound       67
# 9   2023-01-01     6        6           1       01      Inbound       62
#
#    time_point_order  point_type        scheduled_dt  ... delay_minutes  \
# 0                 1  Startpoint 2023-01-01 06:05:00  ...      0.066667
# 1                 2    Midpoint 2023-01-01 06:09:00  ...     -2.533333
# 2                 3    Midpoint 2023-01-01 06:12:00  ...     -3.050000
# 3                 4    Midpoint 2023-01-01 06:15:00  ...     -2.316667
# 4                 5    Midpoint 2023-01-01 06:19:00  ...     -2.416667
# 5                 6    Midpoint 2023-01-01 06:21:00  ...      0.650000
# 6                 7    Midpoint 2023-01-01 06:25:00  ...     -1.066667
# 7                 1  Startpoint 2023-01-01 06:25:00  ...     -0.283333
# 8                 2    Midpoint 2023-01-01 06:29:00  ...     -2.016667
# 9                 8    Midpoint 2023-01-01 06:29:00  ...     -0.516667
#
#            event_hour  air_temp_c rel_humidity_pct  precip_mm  wind_dir_deg  \
# 0 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 1 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 2 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 3 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 4 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 5 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 6 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 7 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 8 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
# 9 2023-01-01 06:00:00        12.2             97.0        0.8         210.0
#
#    wind_speed_kmh  pressure_hpa  cloud_cover  weather_condition
# 0            16.6        1004.1          8.0         Light Rain
# 1            16.6        1004.1          8.0         Light Rain
# 2            16.6        1004.1          8.0         Light Rain
# 3            16.6        1004.1          8.0         Light Rain
# 4            16.6        1004.1          8.0         Light Rain
# 5            16.6        1004.1          8.0         Light Rain
# 6            16.6        1004.1          8.0         Light Rain
# 7            16.6        1004.1          8.0         Light Rain
# 8            16.6        1004.1          8.0         Light Rain
# 9            16.6        1004.1          8.0         Light Rain
#
# [10 rows x 22 columns]

# %%
bus_weather_clean.describe()
# Out:
#                         service_date          hour       weekday  \
# count                       46405028  4.640503e+07  4.640503e+07
# mean   2024-01-03 12:18:38.215103232  1.307246e+01  2.676608e+00
# min              2023-01-01 00:00:00  0.000000e+00  0.000000e+00
# 25%              2023-07-03 00:00:00  8.000000e+00  1.000000e+00
# 50%              2024-01-05 00:00:00  1.400000e+01  3.000000e+00
# 75%              2024-07-05 00:00:00  1.800000e+01  4.000000e+00
# max              2024-12-31 00:00:00  2.300000e+01  6.000000e+00
# std                              NaN  6.094504e+00  1.864209e+00
#
#          is_weekend       stop_id  time_point_order  \
# count  4.640503e+07  4.640503e+07      4.640503e+07
# mean   1.965832e-01  1.266493e+04      4.353983e+00
# min    0.000000e+00  2.000000e+00      1.000000e+00
# 25%    0.000000e+00  1.323000e+03      2.000000e+00
# 50%    0.000000e+00  5.098000e+03      4.000000e+00
# 75%    0.000000e+00  1.200300e+04      6.000000e+00
# max    1.000000e+00  8.833210e+05      2.800000e+01
# std    3.974144e-01  2.149126e+04      2.538687e+00
#
#                         scheduled_dt                      actual_dt  \
# count                       46405028                       46405028
# mean   2024-01-04 01:52:16.887102976  2024-01-04 01:52:55.204860672
# min              2023-01-01 00:00:00            2023-01-01 00:00:02
# 25%              2023-07-03 11:22:00            2023-07-03 11:22:24
# 50%              2024-01-05 08:24:00            2024-01-05 08:24:50
# 75%              2024-07-05 22:20:00  2024-07-05 22:19:12.249999872
# max              2024-12-31 23:59:00            2024-12-31 23:59:59
# std                              NaN                            NaN
#
#        delay_seconds  delay_minutes                     event_hour  \
# count   4.640503e+07   4.640503e+07                       46405028
# mean    3.831776e+01   6.386293e-01  2024-01-04 01:22:57.724167680
# min    -8.634000e+04  -1.439000e+03            2023-01-01 00:00:00
# 25%     2.600000e+01   4.333333e-01            2023-07-03 11:00:00
# 50%     1.700000e+02   2.833333e+00            2024-01-05 08:00:00
# 75%     3.980000e+02   6.633333e+00            2024-07-05 22:00:00
# max     8.639900e+04   1.439983e+03            2024-12-31 23:00:00
# std     4.920911e+03   8.201519e+01                            NaN
#
#          air_temp_c  rel_humidity_pct     precip_mm  wind_dir_deg  \
# count  4.640503e+07      4.640503e+07  4.640503e+07  4.640503e+07
# mean   1.230523e+01      6.686836e+01  1.404955e-01  1.986976e+02
# min   -2.280000e+01      1.300000e+01  0.000000e+00  0.000000e+00
# 25%    5.000000e+00      5.300000e+01  0.000000e+00  1.100000e+02
# 50%    1.170000e+01      6.800000e+01  0.000000e+00  2.200000e+02
# 75%    2.000000e+01      8.300000e+01  0.000000e+00  2.900000e+02
# max    3.670000e+01      1.000000e+02  2.180000e+01  3.600000e+02
# std    9.106053e+00      1.956994e+01  8.193298e-01  1.036883e+02
#
#        wind_speed_kmh  pressure_hpa   cloud_cover
# count    4.640503e+07  4.640503e+07  4.640503e+07
# mean     1.696746e+01  1.015882e+03  4.789645e+00
# min      0.000000e+00  9.790000e+02  0.000000e+00
# 25%      1.120000e+01  1.010700e+03  2.000000e+00
# 50%      1.660000e+01  1.016000e+03  5.000000e+00
# 75%      2.230000e+01  1.021500e+03  8.000000e+00
# max      7.960000e+01  1.047300e+03  8.000000e+00
# std      8.086031e+00  8.492587e+00  2.632038e+00

# %% [markdown]
# Save file

# %%
bus_weather_clean.to_csv("processdata/bus_weather_clean.csv", index=False)
print("Saved as bus_weather_clean.csv")
# Out:
# Saved as bus_weather_clean.csv
